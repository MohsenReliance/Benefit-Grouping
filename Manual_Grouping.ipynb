# %%
# !pip install snowflake-connector-python
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from snowflake.connector import connect
import pandas as pd
import snowflake
# Out:
# /Users/abdulrahmanmohsen/opt/miniconda3/envs/reliance_health/lib/python3.9/site-packages/snowflake/connector/options.py:108: UserWarning: You have an incompatible version of 'pyarrow' installed (8.0.0), please install a version that adheres to: 'pyarrow<10.1.0,>=10.0.1; extra == "pandas"'
#   warn_incompatible_dep(

# %%
conns = {'SnowflakeDB':{ 'UserName': 'ABDULRAHMAN','Password':'Vw963!v!W4!y', 'Host':'rh08312.us-east-2.aws'}}

# %%
connection = snowflake.connector.connect( 
    user=conns['SnowflakeDB']['UserName']
    , password=conns['SnowflakeDB']['Password']
    , account=conns['SnowflakeDB']['Host'])

# %%
raw_data = pd.read_sql("SELECT * FROM DATA_SCIENCE_DB.PUBLIC.PRODUCT_BENEFIT_DOMAIN", connection)
# Out:
# /Users/abdulrahmanmohsen/opt/miniconda3/envs/reliance_health/lib/python3.9/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
raw_data.head(3)
# Out:
#                     BENEFIT_NAME  PRODUCT_ID  BENEFIT_ID  \
# 0  Dialysis And All Related Care        9049         169
# 1                 Eye Swab M/C/S        4478       75658
# 2           Acid Phosphate Serum        9407       75648
#
#                    BENEFIT_GROUP                          VALUE  \
# 0          Renal Care (Dialysis)  Covered (3 Sessions Per Year)
# 1  MICROBIOLOGY AND PARASITOLOGY                        Covered
# 2       CHEMISTRY INVESTIGATIONS                        Covered
#
#            UPDATED_AT  IS_COVERED  IS_GYM  BENEFIT_TOTAL_CLIENTS  \
# 0 2023-03-29 15:18:34           1       0                 2601.0
# 1 2022-01-18 15:10:05           1       0                 2235.0
# 2 2023-04-20 23:09:05           1       0                 2208.0
#
#    TOTAL_CLIENTS  ...  IS_PRODUCT_DIFFERENTIATOR  IS_OBJECT_REMOVAL  \
# 0         2995.0  ...                          1                  0
# 1         2995.0  ...                          1                  0
# ...

# %%
raw_data.head(3)
# Out:
#                     BENEFIT_NAME  PRODUCT_ID  BENEFIT_ID  \
# 0  Dialysis And All Related Care        9049         169
# 1                 Eye Swab M/C/S        4478       75658
# 2           Acid Phosphate Serum        9407       75648
#
#                    BENEFIT_GROUP                          VALUE  \
# 0          Renal Care (Dialysis)  Covered (3 Sessions Per Year)
# 1  MICROBIOLOGY AND PARASITOLOGY                        Covered
# 2       CHEMISTRY INVESTIGATIONS                        Covered
#
#            UPDATED_AT  IS_COVERED  IS_GYM  BENEFIT_TOTAL_CLIENTS  \
# 0 2023-03-29 15:18:34           1       0                 2601.0
# 1 2022-01-18 15:10:05           1       0                 2235.0
# 2 2023-04-20 23:09:05           1       0                 2208.0
#
#    TOTAL_CLIENTS  ...  IS_PRODUCT_DIFFERENTIATOR  IS_OBJECT_REMOVAL  \
# 0         2995.0  ...                          1                  0
# 1         2995.0  ...                          1                  0
# ...

# %%
BENEFIT_DATA = raw_data[['BENEFIT_GROUP', 'BENEFIT_GROUP_COVERAGE', 'BENEFIT_NAME']]

# %%
BENEFIT_DATA.head(3)
# Out:
#                    BENEFIT_GROUP BENEFIT_GROUP_COVERAGE  \
# 0          Renal Care (Dialysis)                Covered
# 1  MICROBIOLOGY AND PARASITOLOGY                Covered
# 2       CHEMISTRY INVESTIGATIONS                Covered
#
#                     BENEFIT_NAME
# 0  Dialysis And All Related Care
# 1                 Eye Swab M/C/S
# 2           Acid Phosphate Serum

# %%
partially_covered_benefit_data = BENEFIT_DATA[BENEFIT_DATA['BENEFIT_GROUP_COVERAGE'] == 'Partially Covered']

# %%
partially_covered_benefit_data
# Out:
#                                              BENEFIT_GROUP  \
# 8                              ADVANCED DIAGNOSTIC IMAGING
# 10             ADVANCED LABORATORY INVESTIGATION/PATHOLOGY
# 14                                      Physiotherapy Care
# 15                     Additional Immunization (0-5 Years)
# 18                                      Physiotherapy Care
# ...                                                    ...
# 3722097        ADVANCED LABORATORY INVESTIGATION/PATHOLOGY
# 3722103                                  EYE/ OPTICAL CARE
# 3722112  WELLNESS CHECKS (TO BE ACCESSED AT DESIGNATED ...
# 3722116                                             Limits
# 3722118        ADVANCED LABORATORY INVESTIGATION/PATHOLOGY
#
#         BENEFIT_GROUP_COVERAGE  \
# 8            Partially Covered
# 10           Partially Covered
# 14           Partially Covered
# 15           Partially Covered
# 18           Partially Covered
# ...                        ...
# ...

# %%
partially_covered_benefits = partially_covered_benefit_data.groupby('BENEFIT_GROUP')['BENEFIT_NAME'].apply(list)

# %%
partially_covered_benefits = pd.DataFrame(partially_covered_benefit_data.groupby('BENEFIT_GROUP')['BENEFIT_NAME'].apply(list)).reset_index()

# %%
set(partially_covered_benefits['BENEFIT_NAME'][1])
# Out:
# {'Arthroscopy',
#  'Bronchoscopy',
#  'Colonoscopy',
#  'Computed Tomography Scan, CT Scan',
#  'Cystoscopy',
#  'Doppler Ultrasound scan',
#  'Echocardiography, Echo',
#  'Electrocardiography, ECG (Pre & Post Exercise)',
#  'Endoscopic Retrograde Cholangiopancreatography (ERCP)',
#  'Endoscopic Ultrasound',
#  'Enteroscopy',
#  'Gastroduodenoscopy (Upper GI endoscopy)',
#  'Gastroscopy',
#  'Hysteroscopy',
#  'Laparoscopy',
#  'Laryngoscopy (Direct And Indirect)',
#  'Magnetic Resonance Imaging, Mri',
#  'Proctoscopy',
#  'Sigmoidoscopy',
#  'Thoracoscopy'}

# %%
partially_covered_benefits
# Out:
#                                         BENEFIT_GROUP  \
# 0                     ACCESS TO FREE TELEMEDICINE APP
# 1                         ADVANCED DIAGNOSTIC IMAGING
# 2         ADVANCED LABORATORY INVESTIGATION/PATHOLOGY
# 3                 Additional Immunization (0-5 Years)
# 4         Additional Immunization (6 Years And Above)
# 5                        Admissions And Accommodation
# 6                  Advanced Laboratory Investigations
# 7                            BASIC DIAGNOSTIC IMAGING
# 8   CANCER CARE (CANCER LIMIT INCLUDES ALL RELATED...
# 9                                CARE FOR THE NEWBORN
# 10                           CHEMISTRY INVESTIGATIONS
# 11                                       DENTAL CARE
# 12                                  EYE/ OPTICAL CARE
# 13                                           Eye Care
# 14                                    Family Planning
# 15                             HIV Care And Treatment
# ...

# %%
set(partially_covered_benefits['BENEFIT_NAME'][30])
# Out:
# {'Annual Visual Acuity Check (Using Snellen Chart)',
#  'BMI Check',
#  'Blood Cholesterol Check',
#  'Blood Pressure Check (Hypertension Screening)',
#  'Blood Sugar Check (Diabetes Screening)',
#  'Chest X-Ray',
#  'General Physical Examination',
#  'Kidney Function Tests (E, U, And Cr)',
#  'Liver Function Test',
#  'Mammography (For Women ≥ 40 Years Of Age)',
#  'Pap Smear',
#  'Psa Check (For Men ≥ 40 Years Of Age)',
#  'Urinalysis'}

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Free Drug Pick-Up After Concluding Chats With Qualified And Certified Doctors At Designated Pharmacies', case=False), 'Benefit'] = 'Telemedicine Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Free Chats With Qualified And Certified Doctors When In Need Of Any Routine Medical Information'", case=False), 'Benefit'] = 'Telemedicine Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("'Free Telemedicine App With Details Of All Covered Benefits On The Scheme'", case=False), 'Benefit'] = 'Telemedicine Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Free Chats With Qualified And Certified Doctors When In Need Of Care During Any Medical Emergency', case=False), 'Benefit'] = 'Telemedicine Emergency Care'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/385438543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Free Drug Pick-Up After Concluding Chats With Qualified And Certified Doctors At Designated Pharmacies', case=False), 'Benefit'] = 'Telemedicine Services'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/385438543.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Arthroscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Bronchoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Colonoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cystoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Endoscopic Retrograde Cholangiopancreatography (ERCP)', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Endoscopic Ultrasound', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Enteroscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Gastroduodenoscopy (Upper GI endoscopy)', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Gastroscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hysteroscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Laparoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Laryngoscopy (Direct And Indirect)', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Proctoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Sigmoidoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Thoracoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Computed Tomography Scan, CT Scan'", case=False), 'Benefit'] = "Imaging and Scanning Procedures"
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Doppler Ultrasound scan', case=False), 'Benefit'] = 'Imaging and Scanning Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Echocardiography, Echo', case=False), 'Benefit'] = 'Imaging and Scanning Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Magnetic Resonance Imaging, MRI', case=False), 'Benefit'] = 'Imaging and Scanning Procedures'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Electrocardiography, ECG (Pre & Post Exercise)', case=False), 'Benefit'] = 'Electrophysiological Study'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3469410670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Arthroscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3469410670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Bronchoscopy', case=False), 'Benefit'] = 'Endoscopic Procedures'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Bleeding Time', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood urea Nitrogen', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Clotting Time', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Coomb's Test (Indirect)", case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Coomb's Test (Direct)", case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Creatinine phosphokinase Serum', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('D-Dimer', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('G-6PD Screening', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Glycated hemoglobin (HBA1C)', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Iron Serum', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Osmotic Fragility Test', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Protein Electrophoresis', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Serum immunoglobulins/Antibodies', case=False), 'Benefit'] = 'Blood and Immunological Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Urate Serum', case=False), 'Benefit'] = 'Blood and Immunological Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chlamydia Screening', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("HIV Confirmatory Test", case=False), 'Benefit'] = "Infection and Disease Screening"
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('HIV Screening', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('epatitis B Screening', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hepatitis B Surface Antigen (HBSAg)', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hepatitis C Screening', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Malaria QBC', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Sputum Acid Fast Bacilli (AFB) Test', case=False), 'Benefit'] = 'Infection and Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Syphilis Screening', case=False), 'Benefit'] = 'Infection and Disease Screening'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Creatinine 24Hr Urine', case=False), 'Benefit'] = "Urine and Renal Function Tests"

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('PSA (Prostate Specific Antigen)', case=False), 'Benefit'] = 'Cancer and Hormonal Disorder Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pap Smear and Cytology', case=False), 'Benefit'] = 'Cancer and Hormonal Disorder Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Thyroid Function Tests', case=False), 'Benefit'] = 'Cancer and Hormonal Disorder Screening'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("CSF M/C/S (CSF Analysis)", case=False), 'Benefit'] = 'Diagnostic and Reproductive Health Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('mmunofluorescence assay', case=False), 'Benefit'] = 'Diagnostic and Reproductive Health Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Semen M/C/S', case=False), 'Benefit'] = 'Diagnostic and Reproductive Health Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Seminal Fluid Analysis (SFA)', case=False), 'Benefit'] = 'Diagnostic and Reproductive Health Tests'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3085740373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Bleeding Time', case=False), 'Benefit'] = 'Blood and Immunological Tests'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3085740373.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood urea Nitrogen', case=False), 'Benefit'] = 'Blood and Immunological Tests'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chicken Pox', case=False), 'Benefit'] = 'Vaccinations and Immunizations'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('MMR', case=False), 'Benefit'] = "Vaccinations and Immunizations"
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Meningitis', case=False), 'Benefit'] = 'Vaccinations and Immunizations'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pneumococcal', case=False), 'Benefit'] = 'Vaccinations and Immunizations'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Rotavirus', case=False), 'Benefit'] = 'Vaccinations and Immunizations'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Typhoid Vaccine', case=False), 'Benefit'] = 'Vaccinations and Immunizations'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/851399375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chicken Pox', case=False), 'Benefit'] = 'Vaccinations and Immunizations'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/851399375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('MMR', case=False), 'Benefit'] = "Vaccinations and Immunizations"
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hepatitis B Vaccine', case=False), 'Benefit'] = 'Specific Disease Prevention Vaccines'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Meningitis Vaccine', case=False), 'Benefit'] = 'Specific Disease Prevention Vaccines'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Yellow Fever', case=False), 'Benefit'] = 'Specific Disease Prevention Vaccines'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/461619603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hepatitis B Vaccine', case=False), 'Benefit'] = 'Specific Disease Prevention Vaccines'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/461619603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Accommodation For In-Patient Care', case=False), 'Benefit'] = 'In-Patient Accommodation and Support'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Accommodation For Parents/Relatives (Excludes Feeding For Parents/Relatives)', case=False), 'Benefit'] = 'In-Patient Accommodation and Support'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Feeding For Enrollees On Admission', case=False), 'Benefit'] = 'In-Patient Accommodation and Support'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood grouping, Cross Matching and transfusion', case=False), 'Benefit'] = 'Medical and Surgical Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hospital Ward Care', case=False), 'Benefit'] = 'Medical and Surgical Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Skilled Medical And Paramedical Services', case=False), 'Benefit'] = 'Medical and Surgical Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Supply Of All Medical And Surgical Consumables', case=False), 'Benefit'] = 'Medical and Surgical Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Supply Of Prescribed Intravenous/Intramuscular, Oral And Topical Drugs', case=False), 'Benefit'] = 'Medical and Surgical Services'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3504323525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Accommodation For In-Patient Care', case=False), 'Benefit'] = 'In-Patient Accommodation and Support'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3504323525.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Accommodation For Parents/Relatives (Excludes Feeding For Parents/Relatives)', case=False), 'Benefit'] = 'In-Patient Accommodation and Support'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Erythrocyte Sedimentation Rate (ESR)", case=False), 'Benefit'] = 'Blood Tests for Hematological Evaluation'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Reticulocyte Count', case=False), 'Benefit'] = 'Blood Tests for Hematological Evaluation'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3196265294.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Erythrocyte Sedimentation Rate (ESR)", case=False), 'Benefit'] = 'Blood Tests for Hematological Evaluation'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3196265294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Erythrocyte Sedimentation Rate (ESR)", case=False), 'Benefit'] = 'Blood Tests for Hematological Evaluation'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Abdominal X-Ray (All views)', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cervical Spine (All views) X-Ray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chest X-Ray (All views)', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Head & Neck Xray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Limb X-Ray (Upper Limbs, Shoulder Joint, Humerus, Elbow Joint, Forearm, Wrist Joint, Wrist Joint, Fingers, Hand, Palm, Hands/Fingers & Palm, Knee, Thumb, Lower Limbs, Hip, Leg, Ankle, Foot, Femur, or T)', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lumbosacral X-Ray (All Views)', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Mandibles/Temporomandibular Joint X-Ray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Mastoid X-Ray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pelvic X-Ray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Sinus X-Ray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Skull X-Ray (All Views)', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Thoracic Inlet X-Ray', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Thoracolumbar X-Ray (Ap & Lateral)', case=False), 'Benefit'] = 'X-Ray Imaging'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('X-Rays Of All Body Joints', case=False), 'Benefit'] = 'X-Ray Imaging'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ultrasound Scans (Obstetrics; Abdominal, Pelvic, Abdominopelvic, Breast, Testicular/Scrotal, Thyroid, Prostate, Bladder, and Brain Ultrasound Scans)', case=False), 'Benefit'] = 'Ultrasound Scans'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/406917628.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Abdominal X-Ray (All views)', case=False), 'Benefit'] = 'X-Ray Imaging'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/406917628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Abdominal X-Ray (All views)', case=False), 'Benefit'] = 'X-Ray Imaging'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cancer-Related Radiological Investigations', case=False), 'Benefit'] = 'Diagnostic and Radiological Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Oncological Investigations', case=False), 'Benefit'] = 'Diagnostic and Radiological Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Oncologist/ Cancer Specialist Visits', case=False), 'Benefit'] = 'Oncology Specialist Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chemotherapy', case=False), 'Benefit'] = 'Cancer Treatment Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Surgical Cancer Care', case=False), 'Benefit'] = 'Cancer Treatment Services'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2326490144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cancer-Related Radiological Investigations', case=False), 'Benefit'] = 'Diagnostic and Radiological Services'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2326490144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Care For Babies Actively On The Plan', case=False), 'Benefit'] = 'Care for Enrolled Neonates'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Care For Babies Not Actively On The Plan (Expires After 6 Weeks Of Life)', case=False), 'Benefit'] = 'Limited Care for Non-Enrolled Neonates'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/593474852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Care For Babies Actively On The Plan', case=False), 'Benefit'] = 'Care for Enrolled Neonates'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/593474852.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Care For Babies Not Actively On The Plan (Expires After 6 Weeks Of Life)', case=False), 'Benefit'] = 'Limited Care for Non-Enrolled Neonates'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('ALT (Sgpt) Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('AST (Sgot) Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Acid Phosphate Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Albumin Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Alkaline Phosphate Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('GGT', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lactate Dehydrogenase Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lipogram (Fasting) (Cholesterol, HDL, LDL, Triglyceride Profile)', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Liver Function and Protein', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Serum Bilirubin (Total and Conjugated)', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Bicarbonate Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Calcium Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chloride Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Inorganic Phosphate Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Magnesium Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Potassium Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Sodium Serum', case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("'U/E + Creatinine' (Urea and Electrolytes)", case=False), 'Benefit'] = 'Electrolytes and Kidney Function Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Glucose Challenge Test', case=False), 'Benefit'] = 'Glucose and Endocrine Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Glucose Fasting', case=False), 'Benefit'] = 'Glucose and Endocrine Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Glucose Random', case=False), 'Benefit'] = 'Glucose and Endocrine Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Oral Glucose Tolerance Test (OGTT)', case=False), 'Benefit'] = 'Glucose and Endocrine Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Inr/Pt (Prothrombin time)', case=False), 'Benefit'] = 'Coagulation and Other Specific Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lithium Serum', case=False), 'Benefit'] = 'Coagulation and Other Specific Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Urine Pregnancy Test', case=False), 'Benefit'] = 'Coagulation and Other Specific Tests'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/1724088709.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('ALT (Sgpt) Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/1724088709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('ALT (Sgpt) Serum', case=False), 'Benefit'] = 'Liver Function and Metabolic Tests'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Preventive Dental Care And Counselling', case=False), 'Benefit'] = 'Preventive and Routine Dental Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Routine Dental Examination', case=False), 'Benefit'] = 'Preventive and Routine Dental Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Scaling And Polishing', case=False), 'Benefit'] = 'Preventive and Routine Dental Care'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Amalgam Filling', case=False), 'Benefit'] = 'Restorative Dental Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Composite Filling', case=False), 'Benefit'] = 'Restorative Dental Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Root Canal Therapy'", case=False), 'Benefit'] = 'Restorative Dental Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Operculectomy', case=False), 'Benefit'] = 'Restorative Dental Procedures'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Dental Pain Therapy', case=False), 'Benefit'] = 'Dental Pain Management and Therapy'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Incision And Drainage', case=False), 'Benefit'] = 'Dental Pain Management and Therapy'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Gingival Curettage', case=False), 'Benefit'] = 'Dental Pain Management and Therapy'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pharmacological Treatment Of Acute And Chronic Dental Infections', case=False), 'Benefit'] = 'Dental Infection Treatment'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Non-Surgical Extraction', case=False), 'Benefit'] = 'Dental Surgical Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Surgical Extraction', case=False), 'Benefit'] = 'Dental Surgical Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Incision And Drainage', case=False), 'Benefit'] = 'Dental Surgical Procedures'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Specialist Dental Consultation', case=False), 'Benefit'] = 'Specialist Dental Services'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2122091818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Preventive Dental Care And Counselling', case=False), 'Benefit'] = 'Preventive and Routine Dental Care'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2122091818.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Advanced Ocular Tests', case=False), 'Benefit'] = 'Basic Ocular Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Basic Ocular Tests', case=False), 'Benefit'] = 'Basic Ocular Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lenses And Frames (Including Contact Lenses)', case=False), 'Benefit'] = 'Corrective Eyewear'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pharmacological Treatment Of Acute And Chronic Ocular Infections', case=False), 'Benefit'] = 'Treatment of Ocular Conditions'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Specialist Ophthalmologist Consultation', case=False), 'Benefit'] = 'Specialist Ophthalmological Services'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3724204598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Advanced Ocular Tests', case=False), 'Benefit'] = 'Basic Ocular Tests'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3724204598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Basic Ocular Tests', case=False), 'Benefit'] = 'Basic Ocular Tests'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ophthalmic Surgeries', case=False), 'Benefit'] = 'Ophthalmic Surgical Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Routine Ocular Examination', case=False), 'Benefit'] = 'Eye Examination and Preventive Care'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3063364406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ophthalmic Surgeries', case=False), 'Benefit'] = 'Ophthalmic Surgical Procedures'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3063364406.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Contraceptive Pills', case=False), 'Benefit'] = 'Hormonal Contraceptives'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Implanon', case=False), 'Benefit'] = 'Hormonal Contraceptives'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Injectibles (Depo Provera, Noristerat)', case=False), 'Benefit'] = 'Hormonal Contraceptives'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Jadelle Implant', case=False), 'Benefit'] = 'Hormonal Contraceptives'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Norplant', case=False), 'Benefit'] = 'Hormonal Contraceptives'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Copper T Intrauterine Device', case=False), 'Benefit'] = 'Intrauterine Devices (IUDs)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lippes Loop Intrauterine Device', case=False), 'Benefit'] = 'Intrauterine Devices (IUDs)'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/532440655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Contraceptive Pills', case=False), 'Benefit'] = 'Hormonal Contraceptives'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/532440655.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Implanon', case=False), 'Benefit'] = 'Hormonal Contraceptives'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Counselling Sessions', case=False), 'Benefit'] = 'Mental Health and Counseling Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Psychotherapy', case=False), 'Benefit'] = 'Mental Health and Counseling Services'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('HIV Specialist Consultation', case=False), 'Benefit'] = 'Infectious Disease Specialist Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Specialist Drug Therapy', case=False), 'Benefit'] = 'Targeted Pharmacotherapy'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3968047002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Counselling Sessions', case=False), 'Benefit'] = 'Mental Health and Counseling Services'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3968047002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Full/Complete Blood Count', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Red Blood Cell Count', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('White Blood Cell Count', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('White Cell Count and Differentials', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Haemoglobin (HB)', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('MCH', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('MCHC', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('MCV', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Packed Cell Volume', case=False), 'Benefit'] = 'Hematological Profiles'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Sedimentation Rate (ESR)', case=False), 'Benefit'] = 'Hematological Profiles'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood group (on request by clinician)', case=False), 'Benefit'] = 'Blood Typing and Compatibility Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Grouping and Cross Matching', case=False), 'Benefit'] = 'Blood Typing and Compatibility Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Film', case=False), 'Benefit'] = 'Diagnostic and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Pregnancy (Beta HCG) Test', case=False), 'Benefit'] = 'Diagnostic and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Genotype (on request by clinician)', case=False), 'Benefit'] = 'Diagnostic and Screening Tests'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2561226457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Full/Complete Blood Count', case=False), 'Benefit'] = 'Hematological Profiles'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2561226457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Red Blood Cell Count', case=False), 'Benefit'] = 'Hematological Profiles'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Fertility Specialist Consultation And Counselling', case=False), 'Benefit'] = 'Fertility Specialist Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Fertility Investigations', case=False), 'Benefit'] = 'Fertility Specialist Services'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2313499564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Fertility Specialist Consultation And Counselling', case=False), 'Benefit'] = 'Fertility Specialist Services'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2313499564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Adenoidectomy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Appendicectomy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cholecystectomy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hernioraphy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Herniotomy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Fistulectomy', case=False), 'Benefit'] = 'Urological and Reproductive System Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Repair Of Penile Avulsion', case=False), 'Benefit'] = 'Urological and Reproductive System Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Varicocelectomy', case=False), 'Benefit'] = 'Urological and Reproductive System Surgeries'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ganglionectomy', case=False), 'Benefit'] = 'Dermatological and Minor Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lumpectomy', case=False), 'Benefit'] = 'Dermatological and Minor Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Wedge Resection Of Ingrowing Toe Nail'", case=False), 'Benefit'] = 'Dermatological and Minor Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Surgical Drainage Of Anal Abscesses', case=False), 'Benefit'] = 'Dermatological and Minor Surgeries'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pterygium Excision', case=False), 'Benefit'] = 'Ophthalmic and Eye-Related Surgery'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Manual Vacuum Aspiration', case=False), 'Benefit'] = 'Gynecological and Obstetric Surgery'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3460163755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Adenoidectomy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3460163755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Appendicectomy', case=False), 'Benefit'] = 'General and Abdominal Surgeries'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('CT Scan', case=False), 'Benefit'] = 'Diagnostic and Medical Imaging Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Echocardiography', case=False), 'Benefit'] = 'Diagnostic and Medical Imaging Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('MRI', case=False), 'Benefit'] = 'Diagnostic and Medical Imaging Services'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cancer Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Fertility Investigations', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Fertility Specialist Consultation and Counselling'", case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Incubator Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Intensive Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Mental Illnesses', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Obstetrics Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Physiotherapy Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Postnatal Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Renal Care', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Specialist Consultation', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Surgeries', case=False), 'Benefit'] = 'Specialized Medical Services and Care'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Lenses and Frames', case=False), 'Benefit'] = 'Vision Care'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Gym', case=False), 'Benefit'] = 'Health and Wellness Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Spa', case=False), 'Benefit'] = 'Health and Wellness Services'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Accommodation for Relatives of Patients on Admission', case=False), 'Benefit'] = 'Healthcare Accommodation'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Accommodation for In-Patient Care', case=False), 'Benefit'] = 'Healthcare Accommodation'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('After-Demise Care', case=False), 'Benefit'] = 'Healthcare Accommodation'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Dental Limit', case=False), 'Benefit'] = 'Healthcare Coverage and Limits'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Optical Limit', case=False), 'Benefit'] = 'Healthcare Coverage and Limits'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Total Limit', case=False), 'Benefit'] = 'Healthcare Coverage and Limits'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Other Dependants', case=False), 'Benefit'] = 'Healthcare Coverage and Limits'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Spouse', case=False), 'Benefit'] = 'Healthcare Coverage and Limits'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Children', case=False), 'Benefit'] = 'Healthcare Coverage and Limits'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3690512211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('CT Scan', case=False), 'Benefit'] = 'Diagnostic and Medical Imaging Services'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3690512211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Echocardiography', case=False), 'Benefit'] = 'Diagnostic and Medical Imaging Services'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Aspirates M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Culture', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ear Swab M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Endocervical Swab (ECS) M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Eye Swab M/C/S'", case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('High Vaginal Swab (HVS) M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Sputum M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Stool M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Throat Swab M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Urethral Swab M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Urine M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Wound Swab M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Helicobacter Pylori Stool Ag test', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Leishmania Screening', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Malaria Parasite (MP)', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Skin Scraping for Fungi', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Skin Snip for Microfilaria', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Stool Occult Blood', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Toxoplasma Screening', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Trypanosomes Screening', case=False), 'Benefit'] = 'Parasitological and Screening Tests'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Mantoux/Heaf's Test", case=False), 'Benefit'] = 'Sexually Transmitted Disease and Other Specific Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('VDRL (Venereal Disease Research Laboratory) Test', case=False), 'Benefit'] = 'Sexually Transmitted Disease and Other Specific Tests'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3131273497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Aspirates M/C/S', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3131273497.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Culture', case=False), 'Benefit'] = 'Culture and Sensitivity Tests (M/C/S)'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hysterectomy', case=False), 'Benefit'] = 'Gynecological Surgeries'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Mastectomy', case=False), 'Benefit'] = 'Oncological Surgeries'
                                                                                            
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains("Open Reduction And Internal Fixation", case=False), 'Benefit'] = 'Orthopedic Surgery'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Thyroidectomy', case=False), 'Benefit'] = 'Endocrine Surgery'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2268521126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hysterectomy', case=False), 'Benefit'] = 'Gynecological Surgeries'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2268521126.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Mastectomy', case=False), 'Benefit'] = 'Oncological Surgeries'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ear Piercing', case=False), 'Benefit'] = 'Body Modifications and Routine Procedures'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Male Circumcision', case=False), 'Benefit'] = "Body Modifications and Routine Procedures"

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Incision & Drainage Of Acute And Chronic Abscesses', case=False), 'Benefit'] = 'Abscess and Wound Management'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Suturing Of Lacerations', case=False), 'Benefit'] = 'Abscess and Wound Management'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Suturing Of Minor Wounds', case=False), 'Benefit'] = 'Abscess and Wound Management'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Removal of foreign objects from superficial wounds, ears, superficial parts of the eye', case=False), 'Benefit'] = 'Foreign Object and Ingrown Toenail Removal'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Removal of ingrown toenail', case=False), 'Benefit'] = 'Foreign Object and Ingrown Toenail Removal'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/915570021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Ear Piercing', case=False), 'Benefit'] = 'Body Modifications and Routine Procedures'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/915570021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('BCG', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('DPT', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hepatitis B', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Measles', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('OPV/IPV', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pentavalent', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Vitamin A', case=False), 'Benefit'] = 'Nutritional Supplements'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/1841029450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('BCG', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/1841029450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('DPT', case=False), 'Benefit'] = 'Vaccinations for Infectious Diseases'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Antenatal Care (Including All Specialist Care And Anc Drugs)', case=False), 'Benefit'] = 'Antenatal Care'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Assisted Delivery (Forceps/Vacuum Delivery)', case=False), 'Benefit'] = 'Delivery and Childbirth Methods'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Caesarian Section', case=False), 'Benefit'] = 'Delivery and Childbirth Methods'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Delivery (Multiple)', case=False), 'Benefit'] = 'Delivery and Childbirth Methods'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Delivery (SVD/Normal And Complicated)', case=False), 'Benefit'] = 'Delivery and Childbirth Methods'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Therapeutic Abortion (Manual Vacuum Aspiration)', case=False), 'Benefit'] = "Post-Conception Procedures"
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3142392646.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Antenatal Care (Including All Specialist Care And Anc Drugs)', case=False), 'Benefit'] = 'Antenatal Care'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3142392646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Antenatal Care (Including All Specialist Care And Anc Drugs)', case=False), 'Benefit'] = 'Antenatal Care'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Access To Prescribed Drugs', case=False), 'Benefit'] = 'Medication and Pharmacy'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cervical Collar And Crutches', case=False), 'Benefit'] = 'Mobility Aids'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Crutches', case=False), 'Benefit'] = 'Mobility Aids'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Walker', case=False), 'Benefit'] = 'Mobility Aids'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pain Therapy', case=False), 'Benefit'] = 'Therapy and Rehabilitation'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Routine Fitness Examination', case=False), 'Benefit'] = 'Therapy and Rehabilitation'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Number Of Sessions Covered', case=False), 'Benefit'] = 'Medical Consultations and Sessions'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Specialist Consultation', case=False), 'Benefit'] = 'Medical Consultations and Sessions'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Preventive Counselling On Referral', case=False), 'Benefit'] = 'Preventive Care and Counseling'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/811355551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Access To Prescribed Drugs', case=False), 'Benefit'] = 'Medication and Pharmacy'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/811355551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cervical Collar And Crutches', case=False), 'Benefit'] = 'Mobility Aids'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Diagnosis Confirmation From Secondary And Tertiary Care Centres', case=False), 'Benefit'] = 'Diagnosis Confirmation'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Line Of Treatment Confirmation From Secondary And Tertiary Care Centres', case=False), 'Benefit'] = 'Treatment Confirmation'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Line Of Treatment Confirmation From Internationally Certified Medical And Surgical Specialists Outside Africa', case=False), 'Benefit'] = 'Treatment Confirmation'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/231984898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Diagnosis Confirmation From Secondary And Tertiary Care Centres', case=False), 'Benefit'] = 'Diagnosis Confirmation'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/231984898.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Group (On Request By Clinician)', case=False), 'Benefit'] = 'Specialized Diagnostic Tests (On Request By Clinician)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Genotype (On Request By Clinician)', case=False), 'Benefit'] = 'Specialized Diagnostic Tests (On Request By Clinician)'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('HIV Screening (On Request By Clinician)', case=False), 'Benefit'] = 'Infectious Disease Screening'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Hepatitis B Screening (On Request By Clinician)', case=False), 'Benefit'] = 'Infectious Disease Screening'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/204955797.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Group (On Request By Clinician)', case=False), 'Benefit'] = 'Specialized Diagnostic Tests (On Request By Clinician)'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/204955797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Group (On Request By Clinician)', case=False), 'Benefit'] = 'Specialized Diagnostic Tests (On Request By Clinician)'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Body Massage', case=False), 'Benefit'] = 'Wellness and Spa Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Facials', case=False), 'Benefit'] = 'Wellness and Spa Services'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Spa Care', case=False), 'Benefit'] = 'Wellness and Spa Services'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2862833345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Body Massage', case=False), 'Benefit'] = 'Wellness and Spa Services'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/2862833345.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Facials', case=False), 'Benefit'] = 'Wellness and Spa Services'
# ...

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Annual Visual Acuity Check (Using Snellen Chart)', case=False), 'Benefit'] = 'Visual and Physical Health Assessments'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('BMI Check', case=False), 'Benefit'] = 'Visual and Physical Health Assessments'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('General Physical Examination', case=False), 'Benefit'] = 'Visual and Physical Health Assessments'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Pressure Check (Hypertension Screening)', case=False), 'Benefit'] = 'Cardiovascular Health Checks'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Cholesterol Check', case=False), 'Benefit'] = 'Cardiovascular Health Checks'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Blood Sugar Check (Diabetes Screening)', case=False), 'Benefit'] = 'Metabolic and Endocrine Health Checks'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chest X-Ray', case=False), 'Benefit'] = 'Imaging and Radiology Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Mammography (For Women ≥ 40 Years Of Age)', case=False), 'Benefit'] = 'Imaging and Radiology Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pap Smear', case=False), 'Benefit'] = 'Cancer Screening Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Psa Check (For Men ≥ 40 Years Of Age)', case=False), 'Benefit'] = 'Cancer Screening Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Kidney Function Tests (E, U, And Cr)', case=False), 'Benefit'] = 'Organ Function Tests'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Liver Function Test', case=False), 'Benefit'] = 'Organ Function Tests'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Urinalysis', case=False), 'Benefit'] = 'Urinary Analysis'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3984691573.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Annual Visual Acuity Check (Using Snellen Chart)', case=False), 'Benefit'] = 'Visual and Physical Health Assessments'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3984691573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Annual Visual Acuity Check (Using Snellen Chart)', case=False), 'Benefit'] = 'Visual and Physical Health Assessments'
# ...

# %%
partially_covered_benefit_data.to_csv('partially_covered_benefit_data.csv')

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Chemotherapy', case=False), 'Benefit'] = 'Cancer Treatment Services'

# %%
partially_covered_benefit_data['Benefit'].unique()
# Out:
# array(['Endoscopic Procedures', 'Blood and Immunological Tests', nan,
#        'Vaccinations and Immunizations',
#        'Cancer and Hormonal Disorder Screening',
#        'Specific Disease Prevention Vaccines',
#        'Infection and Disease Screening',
#        'Imaging and Scanning Procedures',
#        'In-Patient Accommodation and Support',
#        'Diagnostic and Reproductive Health Tests', 'X-Ray Imaging',
#        'Medical and Surgical Services', 'Urine and Renal Function Tests',
#        'Telemedicine Services',
#        'Blood Tests for Hematological Evaluation',
#        'Diagnostic and Radiological Services',
#        'Cancer Treatment Services', 'Oncology Specialist Services',
#        'Telemedicine Emergency Care'], dtype=object)

# %%
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cardiologist', case=False), 'Benefit'] = 'Cardiac Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cardiothoracic Surgeon', case=False), 'Benefit'] = 'Endoscopic Procedures'



partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('General Surgeon', case=False), 'Benefit'] = 'Surgical Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Neurosurgeon', case=False), 'Benefit'] = 'Surgical Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Oral And Maxillofacial Surgeon', case=False), 'Benefit'] = 'Surgical Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Orthopedic Surgeon', case=False), 'Benefit'] = 'Surgical Care'

partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Neonatologist', case=False), 'Benefit'] = 'Pediatric and Neonatal Care'
partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Pediatrician', case=False), 'Benefit'] = 'Pediatric and Neonatal Care'
# Out:
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3771117570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cardiologist', case=False), 'Benefit'] = 'Cardiac Care'
# /var/folders/k_/pdztq4ls169gjt6b3pn7yx640000gn/T/ipykernel_21262/3771117570.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partially_covered_benefit_data.loc[partially_covered_benefit_data.BENEFIT_NAME.str.contains('Cardiothoracic Surgeon', case=False), 'Benefit'] = 'Endoscopic Procedures'
# ...
